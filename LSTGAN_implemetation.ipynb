# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyoti-Yadav-PhD/Survey-data/blob/main/LSTGAN_implemetation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

os.makedirs('LSTGAN/data', exist_ok=True)
os.makedirs('LSTGAN/model', exist_ok=True)

# Create files in LSTGAN/data
open('LSTGAN/data/pems03_loader.py', 'a').close()
open('LSTGAN/data/preprocessing.py', 'a').close()

# Create files in LSTGAN/model
open('LSTGAN/model/temporal_encoder.py', 'a').close()
open('LSTGAN/model/spatial_gcn.py', 'a').close()
open('LSTGAN/model/spatial_attention.py', 'a').close()
open('LSTGAN/model/st_encoder.py', 'a').close()
open('LSTGAN/model/decoder.py', 'a').close()
open('LSTGAN/model/lstgan.py', 'a').close()

# Create top-level files
open('LSTGAN/train.py', 'a').close()
open('LSTGAN/evaluate.py', 'a').close()
open('LSTGAN/config.yaml', 'a').close()

print("Project structure created successfully in 'LSTGAN/'")
# Out:
# Project structure created successfully in 'LSTGAN/'

# %%
# !ls -R LSTGAN
# Out:
# LSTGAN:
# config.yaml  data  evaluate.py	model  train.py
#
# LSTGAN/data:
# pems03_loader.py  preprocessing.py
#
# LSTGAN/model:
# decoder.py  spatial_attention.py  st_encoder.py
# lstgan.py   spatial_gcn.py	  temporal_encoder.py

# %%
os.makedirs('LSTGAN/utils', exist_ok=True)
open('LSTGAN/utils/metrics.py', 'a').close()

# %%
open('LSTGAN/utils/evaluate.py', 'a').close()

# %%
open('LSTGAN/test.py', 'a').close()
